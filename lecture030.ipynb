# %%
# Type Conversion:

print(str(100))
# Out:
# 100

# %%
print(type(str(100)))
# Out:
# <class 'str'>

# %%
print(type(int(str(100))))
# Out:
# <class 'int'>

# %%
a = str(100)
b = int(a)
c = type(b)

print(c)
# Out:
# <class 'int'>
